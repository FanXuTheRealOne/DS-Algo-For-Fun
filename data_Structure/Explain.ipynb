# %% [markdown]
# ### Definition of Linear and non-linear
#
# - Linear data structure：sequential data. There is always a predecessor and successor.
# - Non-linear data structure: Not a one-to-one relation. Need to be presented in Tree or Graph.
